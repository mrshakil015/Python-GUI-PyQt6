# %% [markdown]
# pandas,
# pandasai

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI

df = pd.read_csv("supermarket_sales.csv")
df = df[['Gender', 'Product line', 'Total']]

OPENAI_API_KEY = "k-mtujzCGAyXF5x2gLcLBDT3BlbkFJVLdrDwDxsKnpEkhzV7t"

llm = OpenAI(api_token= OPENAI_API_KEY)

pandas_ai = PandasAI(llm)

# %%
pandas_ai.run(df, prompt="What is the total in Total Line")
# Out:
# 57877.459500000004

# %%
pandas_ai.run(df, prompt="How many male and female gender in Gender line")
# Out:
# Female    76
# Male      73
# Name: Gender, dtype: int64

# %%
pandas_ai.run(df, prompt="Calculate the total spent by each gender")
# Out:
# Gender
# Female    29256.8850
# Male      28620.5745
# Name: Total, dtype: float64

# %%
pandas_ai.run(df, prompt="can you create a barplot that displays the total amount spent by each gender? also add the red and green color in barplot")

# %%
pandas_ai.run(df,prompt="provide me a bar chat between Unit price and Quantity summation")

# %%
pivot_table = df.pivot_table(index='Gender',
                             columns='Product line',
                             values='Total',
                             aggfunc='sum').round(0)
pivot_table
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                        4639.0               3994.0              4967.0
# Male                          4125.0               3482.0              3295.0
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                   5482.0              4509.0             5666.0
# Male                     6086.0              4287.0             7346.0

# %%
pandas_ai.run(pivot_table, prompt="Make a pieplot that shows how much money each gender spends on each product line")
